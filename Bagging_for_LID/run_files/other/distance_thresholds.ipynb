# %%
from Bagging_for_LID.run_files.other.distance_threshold_tests_running import *

# %%
save_dir = r'./Output'
save_dir = pathlib.Path(save_dir)
save_dir.mkdir(parents=True, exist_ok=True)

# %%
K=20
load_data=True
load_threshold_results=True
load_lid_mse_results=True
multiprocess=True
worker_count=5
directory=r"C:\pkls"

# %%
threshold_results, lid_results = threshold_testing(K=20, load_data=load_data, load_threshold_results=load_threshold_results,
                                                   load_lid_mse_results=load_lid_mse_results, multiprocess=multiprocess,
                                                   worker_count=worker_count, directory=directory, save_path=save_dir)
